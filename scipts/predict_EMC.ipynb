# %%
import subprocess

# %%
fasta_path = "path/to/file.fasta"
process = subprocess.Popen(["uv", "run", "python3", "prediction.py", f'"{fasta_path}"'], cwd="..")
print("The affinity prodiction can be found in: predicted_affinity.csv")
